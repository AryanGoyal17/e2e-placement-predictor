# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %% [markdown]
# ## Steps involved in end to end ML pipeline
#
# ### Step-1-- Framing the problem
# ### Step-2-- Data collection
# ### Step-3-- Data preprocessing, EDA and Feature selection
# ### Step-4-- Extracting independent and dependent columns and performing train-test split
# ### Step-5-- Scaling of data
# ### Step-6-- Training, testing and evaluating the model
# ### Step-7-- Plotting the decision boundaries
# ### Step-8-- Converting the model object into a binary file for deployment

# %%
#Step-1 -- Framing the problem
#Step-2 -- Data Collection(toy dataset taken as main goal is to understand end to end pipeline and deployment process)

##-- step1 and step2 done

df = pd.read_csv("../data/placement.csv")

# %%
#Step-3 -- Data preprocessing(handling missing values, dropping irrelevant columns, handling outliers etc...)

df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()

# ---- 0 null values in dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.isnull().sum() #No missing values in dataset
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
#Removing irrelevant column - unnamed

df = df.iloc[:,1:]
print(df.head())

# Step-3 done
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
#Step-4 --- EDA

#Plotting a scatter-plot using matplotlib to understand distribution of data

sns.scatterplot(x = 'cgpa', y = 'iq', hue = 'placement', data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
## Logistic regression will be used to train the model as according to data distribution--
## a line/mathematical fn can be drawn to separate the 2 class(placement - 0/1)

#Step-4 done[outlier detection + handling will be done in later projects as main goal of this project is to understand pipeline and deployment process]

# %%
df.to_csv("../data/processed_data.csv", index = False)
